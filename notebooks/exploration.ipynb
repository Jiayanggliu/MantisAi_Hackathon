# %%
import pandas as pd

scheduler = pd.read_csv("../data/raw/scheduler_data.csv")
dcgm = pd.read_csv("../data/raw/dcgm.csv")

# %%
scheduler.head()

# %%
dcgm.head()

# %%
scheduler.columns.tolist()

# %%
dcgm.columns.tolist()

# %%
print("scheduler:", scheduler.shape)
print("dcgm:", dcgm.shape)
